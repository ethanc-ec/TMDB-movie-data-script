# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_PATH = Path().cwd().parent / 'data'
DATA_PATH
# Out:
# WindowsPath('c:/Users/ethan/Documents/GitHub/ba305/data')

# %%
movies = pd.read_csv(DATA_PATH / 'movies.csv')
movies.head()
# Out:
#        id                title                          genres  \
# 0  436270           Black Adam  Action-Fantasy-Science Fiction
# 1  724495       The Woman King            Action-Drama-History
# 2  829799        Paradise City           Crime-Action-Thriller
# 3  872177  Corrective Measures          Science Fiction-Action
# 4  948276        Lost Bullet 2           Action-Drama-Thriller
#
#   original_language                                           overview  \
# 0                en  Nearly 5000 years after he was bestowed with t...
# 1                en  The story of the Agojie the all-female unit of...
# 2                en  Renegade bounty hunter Ryan Swan must carve hi...
# 3                en  Set in San Tiburon the world's most dangerous ...
# 4                fr  Having cleared his name genius mechanic Lino h...
#
#    popularity                               production_companies release_date  \
# ...

# %%
movies.shape
# Out:
# (735823, 20)

# %%
tmdb = pd.read_csv(DATA_PATH / 'tmdb_5000_movies.csv')
tmdb
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
for i in tmdb['id']:
    if i not in movies['id']:
        print(i)

# %%
[1 for i in tmdb['id'] if i not in movies['id']]
# Out:
# []

# %%
merged = pd.merge(movies, tmdb, how='outer', left_on='id', right_on='id', suffixes=('_movies', '_tmdb'))
merged.describe()
# Out:
#                   id  popularity_movies  budget_movies  revenue_movies  \
# count  735871.000000      735823.000000   7.358230e+05    7.358230e+05
# mean   526545.075210           1.870561   3.828745e+05    9.470205e+05
# std    252309.903274          19.164325   8.083487e+06    1.965047e+07
# min         2.000000           0.600000   0.000000e+00   -1.200000e+01
# 25%    329461.500000           0.600000   0.000000e+00    0.000000e+00
# 50%    533343.000000           0.600000   0.000000e+00    0.000000e+00
# 75%    736080.500000           1.318000   0.000000e+00    0.000000e+00
# max    968161.000000       10405.742000   5.000000e+09    2.920357e+09
#
#        runtime_movies  vote_average_movies  vote_count_movies   budget_tmdb  \
# count    6.986630e+05        735823.000000      735823.000000  4.910000e+03
# mean     1.970302e+02             2.449369          26.339542  2.844178e+07
# std      8.518390e+04             3.175621         367.166008  4.048626e+07
# ...

# %%
merged[['id']].value_counts()
# Out:
# id
# 751820    4
# 548063    3
# 535437    3
# 543335    3
# 452391    3
#          ..
# 968119    1
# 968120    1
# 968121    1
# 968122    1
# 18        1
# Name: count, Length: 662131, dtype: int64

# %%
merged[merged['id'] == 751820]
# Out:
#             id    title_movies       genres_movies original_language_movies  \
# 565376  751820  Caught in Time  Action-Crime-Drama                       zh
# 565377  751820  Caught in Time  Action-Crime-Drama                       zh
# 565378  751820  Caught in Time  Action-Crime-Drama                       zh
# 565379  751820  Caught in Time  Action-Crime-Drama                       zh
#
#                                           overview_movies  popularity_movies  \
# 565376  A detective tracks down a gang of criminals te...              4.775
# 565377  A detective tracks down a gang of criminals te...              4.087
# 565378  A detective tracks down a gang of criminals te...              3.015
# 565379  A detective tracks down a gang of criminals te...              3.015
#
#        production_companies_movies release_date_movies  budget_movies  \
# 565376     Emperor Motion Pictures          2020-11-27            0.0
# ...
